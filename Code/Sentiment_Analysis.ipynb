# %%
import pandas as pd
Reviews=pd.read_csv(r"C:\Users\Prabhat\Desktop\Carear\projects\Sentiment Analysis For New Update\Data\Clash_Royal_Reviews")
Reviews.head()
# Out:
#    Unnamed: 0                                               text  rating  \
# 0           0  Broken decks. Good game, consistently bad upda...     1.0
# 1           1                              pretty addictive tbh.     5.0
# 2           2   change matchmaking system and do less pay to win     2.0
# 3           4  my characters are dumb and slow AF compare to ...     1.0
# 4           8  This game was good and I have been a user sinc...     1.0
#
#                   date            category       source author  \
# 0  2025-11-21 21:31:58  Play_Store_Updates  Google_Play    NaN
# 1  2025-11-21 21:31:19  Play_Store_Updates  Google_Play    NaN
# 2  2025-11-21 21:29:24  Play_Store_Updates  Google_Play    NaN
# 3  2025-11-21 21:25:51  Play_Store_Updates  Google_Play    NaN
# 4  2025-11-21 21:12:06  Play_Store_Updates  Google_Play    NaN
#
#                                         cleaned_text  word_count  text_length
# ...

# %% [markdown]
# ## 🔄 Notebook Status Update
#
# > ⚠️ **Important Note**
# > The original sentiment modeling notebook became corrupted during a GitHub sync.
# > The final dataset and Power BI dashboard fully reflect the completed model results,
# > including sentiment classification and topic extraction.
# >
# > A fully rebuilt version of this notebook is currently being added.

# %%
Reviews=Reviews.drop(columns=["Unnamed: 0"])

# %%
Reviews.head()
# Out:
#                                                 text  rating  \
# 0  Broken decks. Good game, consistently bad upda...     1.0
# 1                              pretty addictive tbh.     5.0
# 2   change matchmaking system and do less pay to win     2.0
# 3  my characters are dumb and slow AF compare to ...     1.0
# 4  This game was good and I have been a user sinc...     1.0
#
#                   date            category       source author  \
# 0  2025-11-21 21:31:58  Play_Store_Updates  Google_Play    NaN
# 1  2025-11-21 21:31:19  Play_Store_Updates  Google_Play    NaN
# 2  2025-11-21 21:29:24  Play_Store_Updates  Google_Play    NaN
# 3  2025-11-21 21:25:51  Play_Store_Updates  Google_Play    NaN
# 4  2025-11-21 21:12:06  Play_Store_Updates  Google_Play    NaN
#
#                                         cleaned_text  word_count  text_length
# 0  Broken decks. Good game, consistently bad upda...          17          110
# ...

# %%
R

# %%
Reviews['Sentiment']
# Out:
# <bound method IndexOpsMixin.value_counts of 0        Negative
# 1        Negative
# 2        Negative
# 3        Negative
# 4        Negative
#            ...
# 17199     Neutral
# 17200     Neutral
# 17201     Neutral
# 17202    Negative
# 17203    Negative
# Name: Sentiment, Length: 17204, dtype: object>

# %%
from collections import Counter
count=Counter(Reviews['Sentiment'])
count
# Out:
# Counter({'Negative': 9419, 'Neutral': 6887, 'Positive': 898})

# %%
Reviews[Reviews['Sentiment']=='Neutral'].sample(10)['cleaned_text']
# Out:
# 2387                         Time to delete the game again
# 12943    Maybe I missed it, but what do I do with my Ev...
# 8509                                   This game cooked fr
# 5178          Aaand the game is going down the drain again
# 6354     Mais uma vez a ganacia da supercell impactando...
# 12423                               Uae them while you can
# 16836    ​ @Rasimlol1380 and I got 50 posions cards fro...
# 15099                           we have gone from 12 to 16
# 11173             They didn’t even add all the evos yet😭😭😭
# 6913                  Just made more evos with extra steps
# Name: cleaned_text, dtype: object
